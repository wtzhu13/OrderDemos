# %%
#读取mnist数据集
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
mnist = input_data.read_data_sets("MNITS_data/",one_hot=True) #这里one_hot为True其实就是说每一条数据对应的标签是一个向量
sess = tf.InteractiveSession() #创建session
#函数声明部分
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)
def bias_variable(shape):
    initial = tf.constant(0.1,shape=shape)
    return tf.Variable(initial)
#tf.nn.conv2d中输入x的shape是[batch, in_height, in_width, in_channels]，滤波器的shape是[filter_height, filter_width, in_channels, out_channels]，strides的shape是[batch, #in_height, in_width, in_channels]，其中strides[0]=strides[3]=1.
def conv2d(x,w):
    return tf.nn.conv2d(x,w,strides=[1,1,1,1],padding='SAME')
#ksize的每一维数值是与输入的每一维相匹配的
def max_pool_2x2(x):
    return tf.nn.max_pool(x,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
#占位操作，定义输入输出、dropout操作的丢弃率的数据类型
xs = tf.placeholder(tf.float32,[None,28*28])
ys = tf.placeholder(tf.float32,[None,10])
keep_prob = tf.placeholder(tf.float32)
#输入
x_image = tf.reshape(xs,[-1,28,28,1])
#第一层卷积层
w_conv1 = weight_variable([5,5,1,32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image,w_conv1)+b_conv1)
h_pool1 = max_pool_2x2(h_conv1)
print(h_pool1)
#第二层卷积层
w_conv2 = weight_variable([5,5,32,64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1,w_conv2)+b_conv2)
h_pool2 = max_pool_2x2(h_conv2)
print(h_pool2)
#平坦化
flat = tf.reshape(h_pool2,[-1,3136])
#第三层全连接层
w_fc1 = weight_variable([3136,1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(flat,w_fc1)+b_fc1)
print(h_fc1)
#Dropout操作
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)
#第四层输出层，使用多分类器softmax
w_fc2 = weight_variable([1024,10])
b_fc2 = bias_variable([10])
y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop,w_fc2)+b_fc2)
print(y_conv)
#定义损失cross_entropy = -tf.reduce_sum(ys*tf.log(y_conv))
cross_entropy = tf.reduce_mean(-tf.reduce_sum(ys*tf.log(y_conv),reduction_indices=[1]))
#优化
train_step = tf.train.GradientDescentOptimizer(0.0001).minimize(cross_entropy)
#精确度
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(ys,1)) #tf.equal返回值true或falae
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
#初始化全部变量
tf.global_variables_initializer().run()
#迭代训练
for i in range (20000):
    batch = mnist.train.next_batch(50)
    train_step.run(feed_dict={xs:batch[0],ys:batch[1],keep_prob:0.5})
    #训练迭代美每100次就用训练数据打印输出精确度，使用训练集数据检测一下模型的训练效果
    if i%100 == 0:
        train_accuracy = accuracy.eval(feed_dict={xs:batch[0],ys:batch[1],keep_prob:1.0})
        print("step %d,training accuracy %g"%(i,train_accuracy))
#测试，使用测试数据检测模型的效果，打印输出精确度
print("test accuracy %g"%accuracy.eval(feed_dict={xs: mnist.test.images,ys:mnist.test.labels,keep_prob:1.0}))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0624 11:44:50.874900 11204 deprecation.py:323] From <ipython-input-1-e5ea65ef23a6>:4: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0624 11:44:50.884900 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# W0624 11:44:50.901504 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# W0624 11:44:53.244372 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNITS_data/train-images-idx3-ubyte.gz
# W0624 11:44:53.772608 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# W0624 11:44:53.772608 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNITS_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNITS_data/t10k-images-idx3-ubyte.gz
# W0624 11:44:55.484541 11204 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNITS_data/t10k-labels-idx1-ubyte.gz
# W0624 11:44:56.179709 11204 deprecation.py:506] From <ipython-input-1-e5ea65ef23a6>:46: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Tensor("MaxPool:0", shape=(?, 14, 14, 32), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 7, 7, 64), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 1024), dtype=float32)
# Tensor("Softmax:0", shape=(?, 10), dtype=float32)
# step 0,training accuracy 0.16
# step 100,training accuracy 0.1
# step 200,training accuracy 0.16
# step 300,training accuracy 0.16
# step 400,training accuracy 0.2
# step 500,training accuracy 0.24
# step 600,training accuracy 0.18
# step 700,training accuracy 0.4
# step 800,training accuracy 0.38
# step 900,training accuracy 0.3
# step 1000,training accuracy 0.5
# step 1100,training accuracy 0.4
# step 1200,training accuracy 0.56
# step 1300,training accuracy 0.52
# step 1400,training accuracy 0.5
# step 1500,training accuracy 0.6
# step 1600,training accuracy 0.52
# step 1700,training accuracy 0.52
# step 1800,training accuracy 0.46
# step 1900,training accuracy 0.6
# step 2000,training accuracy 0.54
# step 2100,training accuracy 0.52
# step 2200,training accuracy 0.68
# step 2300,training accuracy 0.7
# step 2400,training accuracy 0.68
# step 2500,training accuracy 0.6
# step 2600,training accuracy 0.74
# step 2700,training accuracy 0.64
# step 2800,training accuracy 0.72
# step 2900,training accuracy 0.72
# step 3000,training accuracy 0.7
# step 3100,training accuracy 0.72
# step 3200,training accuracy 0.76
# step 3300,training accuracy 0.68
# step 3400,training accuracy 0.62
# step 3500,training accuracy 0.76
# step 3600,training accuracy 0.74
# step 3700,training accuracy 0.84
# step 3800,training accuracy 0.84
# step 3900,training accuracy 0.76
# step 4000,training accuracy 0.74
# step 4100,training accuracy 0.82
# step 4200,training accuracy 0.7
# step 4300,training accuracy 0.84
# step 4400,training accuracy 0.84
# step 4500,training accuracy 0.74
# step 4600,training accuracy 0.84
# step 4700,training accuracy 0.76
# step 4800,training accuracy 0.66
# step 4900,training accuracy 0.82
# step 5000,training accuracy 0.86
# step 5100,training accuracy 0.78
# step 5200,training accuracy 0.94
# step 5300,training accuracy 0.74
# step 5400,training accuracy 0.86
# step 5500,training accuracy 0.82
# step 5600,training accuracy 0.82
# step 5700,training accuracy 0.84
# step 5800,training accuracy 0.82
# step 5900,training accuracy 0.92
# step 6000,training accuracy 0.84
# step 6100,training accuracy 0.76
# step 6200,training accuracy 0.8
# step 6300,training accuracy 0.78
# step 6400,training accuracy 0.92
# step 6500,training accuracy 0.84
# step 6600,training accuracy 0.9
# step 6700,training accuracy 0.92
# step 6800,training accuracy 0.84
# step 6900,training accuracy 0.8
# step 7000,training accuracy 0.82
# step 7100,training accuracy 0.88
# step 7200,training accuracy 0.82
# step 7300,training accuracy 0.86
# step 7400,training accuracy 0.74
# step 7500,training accuracy 0.74
# step 7600,training accuracy 0.8
# step 7700,training accuracy 0.88
# step 7800,training accuracy 0.88
# step 7900,training accuracy 0.78
# step 8000,training accuracy 0.84
# step 8100,training accuracy 0.82
# step 8200,training accuracy 0.82
# step 8300,training accuracy 0.78
# step 8400,training accuracy 0.84
# step 8500,training accuracy 0.9
# step 8600,training accuracy 0.88
# step 8700,training accuracy 0.9
# step 8800,training accuracy 0.86
# step 8900,training accuracy 0.9
# step 9000,training accuracy 0.84
# step 9100,training accuracy 0.82
# step 9200,training accuracy 0.92
# step 9300,training accuracy 0.86
# step 9400,training accuracy 0.94
# step 9500,training accuracy 0.9
# step 9600,training accuracy 0.88
# step 9700,training accuracy 0.88
# step 9800,training accuracy 0.88
# step 9900,training accuracy 0.84
# step 10000,training accuracy 0.94
# step 10100,training accuracy 0.9
# step 10200,training accuracy 0.88
# step 10300,training accuracy 0.86
# step 10400,training accuracy 0.86
# step 10500,training accuracy 0.84
# step 10600,training accuracy 0.92
# step 10700,training accuracy 0.86
# step 10800,training accuracy 0.76
# step 10900,training accuracy 0.84
# step 11000,training accuracy 0.88
# step 11100,training accuracy 0.74
# step 11200,training accuracy 0.9
# step 11300,training accuracy 0.9
# step 11400,training accuracy 0.88
# step 11500,training accuracy 0.84
# step 11600,training accuracy 0.84
# step 11700,training accuracy 0.8
# step 11800,training accuracy 0.9
# step 11900,training accuracy 0.8
# step 12000,training accuracy 0.9
# step 12100,training accuracy 0.92
# step 12200,training accuracy 0.92
# step 12300,training accuracy 0.96
# step 12400,training accuracy 0.86
# step 12500,training accuracy 0.76
# step 12600,training accuracy 0.84
# step 12700,training accuracy 0.9
# step 12800,training accuracy 0.92
# step 12900,training accuracy 0.94
# step 13000,training accuracy 0.92
# step 13100,training accuracy 0.88
# step 13200,training accuracy 0.9
# step 13300,training accuracy 0.9
# step 13400,training accuracy 0.92
# step 13500,training accuracy 0.94
# step 13600,training accuracy 0.84
# step 13700,training accuracy 0.9
# step 13800,training accuracy 0.94
# step 13900,training accuracy 0.88
# step 14000,training accuracy 0.96
# step 14100,training accuracy 0.84
# step 14200,training accuracy 0.88
# step 14300,training accuracy 0.9
# step 14400,training accuracy 0.88
# step 14500,training accuracy 0.94
# step 14600,training accuracy 0.9
# step 14700,training accuracy 0.92
# step 14800,training accuracy 0.96
# step 14900,training accuracy 0.9
# step 15000,training accuracy 0.9
# step 15100,training accuracy 0.92
# step 15200,training accuracy 0.92
# step 15300,training accuracy 0.86
# step 15400,training accuracy 0.86
# step 15500,training accuracy 0.96
# step 15600,training accuracy 0.86
# step 15700,training accuracy 0.9
# step 15800,training accuracy 0.86
# step 15900,training accuracy 0.9
# step 16000,training accuracy 0.9
# step 16100,training accuracy 0.9
# step 16200,training accuracy 0.92
# step 16300,training accuracy 0.94
# step 16400,training accuracy 0.94
# step 16500,training accuracy 0.8
# step 16600,training accuracy 0.88
# step 16700,training accuracy 0.94
# step 16800,training accuracy 0.9
# step 16900,training accuracy 0.92
# step 17000,training accuracy 0.88
# step 17100,training accuracy 0.94
# step 17200,training accuracy 0.84
# step 17300,training accuracy 0.86
# step 17400,training accuracy 0.92
# step 17500,training accuracy 0.9
# step 17600,training accuracy 0.9
# step 17700,training accuracy 0.88
# step 17800,training accuracy 0.86
# step 17900,training accuracy 0.84
# step 18000,training accuracy 0.92
# step 18100,training accuracy 0.92
# step 18200,training accuracy 0.82
# step 18300,training accuracy 0.92
# step 18400,training accuracy 0.88
# step 18500,training accuracy 0.88
# step 18600,training accuracy 0.88
# step 18700,training accuracy 0.86
# step 18800,training accuracy 0.88
# step 18900,training accuracy 0.88
# step 19000,training accuracy 0.96
# step 19100,training accuracy 0.88
# step 19200,training accuracy 0.96
# step 19300,training accuracy 0.86
# step 19400,training accuracy 0.94
# step 19500,training accuracy 0.88
# step 19600,training accuracy 0.96
# step 19700,training accuracy 0.9
# step 19800,training accuracy 0.9
# step 19900,training accuracy 0.94
# test accuracy 0.9195
